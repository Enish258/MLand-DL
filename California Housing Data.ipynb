# %%
import sklearn

# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sklearn.datasets import california_housing

# %%
file="C:/Users/Asus/Downloads/housing.csv"

# %%
data=pd.read_csv(file)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data["total_bedrooms"].isnull().sum()
# Out:
# 207

# %%
data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D73AE66C88>,
# ...
#       dtype=object)

# %%
mean=data["total_bedrooms"].mean()

# %%
data=data.fillna(mean)

# %%
list=data["total_bedrooms"]

# %%
list
# Out:
# 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
# 5         213.0
# 6         489.0
# 7         687.0
# 8         665.0
# 9         707.0
# 10        434.0
# 11        752.0
# 12        474.0
# 13        191.0
# 14        626.0
# 15        283.0
# 16        347.0
# 17        293.0
# 18        455.0
# 19        298.0
# 20        184.0
# 21        367.0
# 22        541.0
# 23        337.0
# 24        437.0
# 25        123.0
# 26        244.0
# 27        421.0
# 28        492.0
# 29        160.0
#           ...
# 20610     484.0
# 20611     441.0
# 20612     289.0
# 20613     365.0
# 20614     460.0
# 20615     216.0
# 20616     441.0
# 20617     109.0
# 20618     247.0
# 20619     340.0
# 20620      41.0
# 20621     247.0
# 20622     147.0
# 20623     244.0
# 20624     300.0
# 20625      17.0
# 20626     184.0
# 20627      65.0
# 20628     421.0
# 20629    1856.0
# 20630     505.0
# 20631     493.0
# 20632     416.0
# 20633     412.0
# ...

# %%
l=DataFrame(list)

# %%
l
# Out:
#        total_bedrooms
# 0               129.0
# 1              1106.0
# 2               190.0
# 3               235.0
# 4               280.0
# 5               213.0
# 6               489.0
# 7               687.0
# 8               665.0
# 9               707.0
# 10              434.0
# 11              752.0
# 12              474.0
# 13              191.0
# 14              626.0
# 15              283.0
# 16              347.0
# 17              293.0
# 18              455.0
# 19              298.0
# 20              184.0
# 21              367.0
# 22              541.0
# 23              337.0
# 24              437.0
# 25              123.0
# 26              244.0
# 27              421.0
# 28              492.0
# 29              160.0
# ...               ...
# 20610           484.0
# 20611           441.0
# 20612           289.0
# 20613           365.0
# 20614           460.0
# 20615           216.0
# 20616           441.0
# 20617           109.0
# 20618           247.0
# ...

# %%
l.isnull().sum()
# Out:
# total_bedrooms    0
# dtype: int64

# %%
for i in l:
    if(pd.isnull(i)==True):
        print(i)
        i=mean
        pass
    pass

# %%
data["total_bedrooms"]=l

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20640 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
l.mean()
# Out:
# total_bedrooms    537.870553
# dtype: float64

# %%
len(l)
# Out:
# 20640

# %%
from sklearn.model_selection import train_test_split

# %%
train_set,test_set=train_test_split(data,test_size=0.2,random_state=42)

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0      537.870553
# 3024     -119.46     35.14                30.0       2943.0      537.870553
# 15663    -122.44     37.80                52.0       3830.0      537.870553
# 20484    -118.72     34.28                17.0       3051.0      537.870553
# 9814     -121.93     36.62                34.0       2351.0      537.870553
# 13311    -117.61     34.08                12.0       4427.0      537.870553
# 7113     -118.02     33.89                36.0       1375.0      537.870553
# 7668     -118.08     33.92                38.0       1335.0      537.870553
# 18246    -122.08     37.39                 4.0       2292.0      537.870553
# 5723     -118.23     34.18                45.0       2332.0      537.870553
# 20069    -120.37     38.01                30.0        473.0      537.870553
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0      537.870553
# 3024     -119.46     35.14                30.0       2943.0      537.870553
# 15663    -122.44     37.80                52.0       3830.0      537.870553
# 20484    -118.72     34.28                17.0       3051.0      537.870553
# 9814     -121.93     36.62                34.0       2351.0      537.870553
# 13311    -117.61     34.08                12.0       4427.0      537.870553
# 7113     -118.02     33.89                36.0       1375.0      537.870553
# 7668     -118.08     33.92                38.0       1335.0      537.870553
# 18246    -122.08     37.39                 4.0       2292.0      537.870553
# 5723     -118.23     34.18                45.0       2332.0      537.870553
# 20069    -120.37     38.01                30.0        473.0      537.870553
# ...

# %%
data=data.fillna(mean)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128 entries, 20046 to 3665
# Data columns (total 10 columns):
# longitude             4128 non-null float64
# latitude              4128 non-null float64
# housing_median_age    4128 non-null float64
# total_rooms           4128 non-null float64
# total_bedrooms        4128 non-null float64
# population            4128 non-null float64
# households            4128 non-null float64
# median_income         4128 non-null float64
# median_house_value    4128 non-null float64
# ocean_proximity       4128 non-null object
# dtypes: float64(9), object(1)
# memory usage: 354.8+ KB

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 14196 to 15795
# Data columns (total 10 columns):
# longitude             16512 non-null float64
# latitude              16512 non-null float64
# housing_median_age    16512 non-null float64
# total_rooms           16512 non-null float64
# total_bedrooms        16512 non-null float64
# population            16512 non-null float64
# households            16512 non-null float64
# median_income         16512 non-null float64
# median_house_value    16512 non-null float64
# ocean_proximity       16512 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.4+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20640 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
train_copy=train_set
train_set.shape
test_set.shape
# Out:
# (4128, 10)

# %%
train_copy
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# 17848    -121.86     37.42                20.0       5032.0           808.0
# 6252     -117.97     34.04                28.0       1686.0           417.0
# 9389     -122.53     37.91                37.0       2524.0           398.0
# 6113     -117.90     34.13                 5.0       1126.0           316.0
# 6061     -117.79     34.02                 5.0      18690.0          2862.0
# 16030    -122.45     37.72                52.0        982.0           197.0
# ...

# %%
corr_matrix=train_copy.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending=True)
# Out:
# latitude             -0.142983
# longitude            -0.046349
# population           -0.026032
# total_bedrooms        0.047980
# households            0.063714
# housing_median_age    0.103706
# total_rooms           0.133989
# median_income         0.690647
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %%
train_copy['rph']=train_copy['total_rooms']/train_copy['households']

# %%
data.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
train_copy.head(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity       rph
# 14196      NEAR OCEAN  5.017657
# 8267       NEAR OCEAN  4.473545
# ...

# %%
corr=train_copy.corr()

# %%
corr['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.690647
# rph                   0.158485
# total_rooms           0.133989
# housing_median_age    0.103706
# households            0.063714
# total_bedrooms        0.047980
# population           -0.026032
# longitude            -0.046349
# latitude             -0.142983
# Name: median_house_value, dtype: float64

# %%
housing=train_copy

# %%
label=train_set["median_house_value"].copy()

# %%
label
# Out:
# 14196    103000.0
# 8267     382100.0
# 17445    172600.0
# 14265     93400.0
# 2271      96500.0
# 17848    264800.0
# 6252     157300.0
# 9389     500001.0
# 6113     139800.0
# 6061     315600.0
# 16030    231900.0
# 8364     159400.0
# 9448      96000.0
# 17529    187500.0
# 5865     229900.0
# 7615     117700.0
# 9707     169600.0
# 16332    130800.0
# 3449     157400.0
# 5199      94100.0
# 13496     72700.0
# 18056    500001.0
# 9529      95800.0
# 5128      97500.0
# 18796     78800.0
# 413      292000.0
# 1175      42500.0
# 4387     187500.0
# 11628    218200.0
# 9787      87500.0
#            ...
# 1267     119400.0
# 1899     100800.0
# 3005      97900.0
# 19118    200600.0
# 189       95500.0
# 2747      97200.0
# 18431    289200.0
# 18942    305200.0
# 8666     420200.0
# 6396     352200.0
# 19769     91700.0
# 17568    167500.0
# 6420     235200.0
# 5051     312500.0
# 5311     500001.0
# 2433      62400.0
# 769      193800.0
# 1685     193300.0
# 8322     100800.0
# ...

# %%
train_copy.head(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity       rph
# 14196      NEAR OCEAN  5.017657
# 8267       NEAR OCEAN  4.473545
# ...

# %%
housing.head(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity       rph
# 14196      NEAR OCEAN  5.017657
# 8267       NEAR OCEAN  4.473545
# ...

# %%
housing.shape
# Out:
# (16512, 11)

# %%
housing = pd.concat([housing,pd.get_dummies(housing['ocean_proximity'], prefix='ocean_proximity')],axis=1)
housing.drop(['ocean_proximity'],axis=1,inplace=True)

# %%
housing.min()
# Out:
# longitude                      -124.350000
# latitude                         32.550000
# housing_median_age                1.000000
# total_rooms                       2.000000
# total_bedrooms                    1.000000
# population                        3.000000
# households                        1.000000
# median_income                     0.499900
# median_house_value            14999.000000
# rph                               0.888889
# ocean_proximity_<1H OCEAN         0.000000
# ocean_proximity_INLAND            0.000000
# ocean_proximity_ISLAND            0.000000
# ocean_proximity_NEAR BAY          0.000000
# ocean_proximity_NEAR OCEAN        0.000000
# dtype: float64

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# 17848    -121.86     37.42                20.0       5032.0           808.0
# 6252     -117.97     34.04                28.0       1686.0           417.0
# 9389     -122.53     37.91                37.0       2524.0           398.0
# 6113     -117.90     34.13                 5.0       1126.0           316.0
# 6061     -117.79     34.02                 5.0      18690.0          2862.0
# 16030    -122.45     37.72                52.0        982.0           197.0
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 14196 to 15795
# Data columns (total 15 columns):
# longitude                     16512 non-null float64
# latitude                      16512 non-null float64
# housing_median_age            16512 non-null float64
# total_rooms                   16512 non-null float64
# total_bedrooms                16512 non-null float64
# population                    16512 non-null float64
# households                    16512 non-null float64
# median_income                 16512 non-null float64
# median_house_value            16512 non-null float64
# rph                           16512 non-null float64
# ocean_proximity_<1H OCEAN     16512 non-null uint8
# ocean_proximity_INLAND        16512 non-null uint8
# ocean_proximity_ISLAND        16512 non-null uint8
# ocean_proximity_NEAR BAY      16512 non-null uint8
# ocean_proximity_NEAR OCEAN    16512 non-null uint8
# dtypes: float64(10), uint8(5)
# memory usage: 1.5 MB

# %%
from sklearn import model_selection

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
lr=LinearRegression()

# %%
house_train,house_test=train_test_split(housing,test_size=0.9,random_state=23)

# %%
house_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1651 entries, 9584 to 9485
# Data columns (total 15 columns):
# longitude                     1651 non-null float64
# latitude                      1651 non-null float64
# housing_median_age            1651 non-null float64
# total_rooms                   1651 non-null float64
# total_bedrooms                1651 non-null float64
# population                    1651 non-null float64
# households                    1651 non-null float64
# median_income                 1651 non-null float64
# median_house_value            1651 non-null float64
# rph                           1651 non-null float64
# ocean_proximity_<1H OCEAN     1651 non-null uint8
# ocean_proximity_INLAND        1651 non-null uint8
# ocean_proximity_ISLAND        1651 non-null uint8
# ocean_proximity_NEAR BAY      1651 non-null uint8
# ocean_proximity_NEAR OCEAN    1651 non-null uint8
# dtypes: float64(10), uint8(5)
# memory usage: 149.9 KB

# %%
label
# Out:
# 14196    103000.0
# 8267     382100.0
# 17445    172600.0
# 14265     93400.0
# 2271      96500.0
# 17848    264800.0
# 6252     157300.0
# 9389     500001.0
# 6113     139800.0
# 6061     315600.0
# 16030    231900.0
# 8364     159400.0
# 9448      96000.0
# 17529    187500.0
# 5865     229900.0
# 7615     117700.0
# 9707     169600.0
# 16332    130800.0
# 3449     157400.0
# 5199      94100.0
# 13496     72700.0
# 18056    500001.0
# 9529      95800.0
# 5128      97500.0
# 18796     78800.0
# 413      292000.0
# 1175      42500.0
# 4387     187500.0
# 11628    218200.0
# 9787      87500.0
#            ...
# 1267     119400.0
# 1899     100800.0
# 3005      97900.0
# 19118    200600.0
# 189       95500.0
# 2747      97200.0
# 18431    289200.0
# 18942    305200.0
# 8666     420200.0
# 6396     352200.0
# 19769     91700.0
# 17568    167500.0
# 6420     235200.0
# 5051     312500.0
# 5311     500001.0
# 2433      62400.0
# 769      193800.0
# 1685     193300.0
# 8322     100800.0
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse=np.sqrt(-res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-79aff1c33191> in <module>
# ----> 1 rmse=np.sqrt(-res)
#
# NameError: name 'res' is not defined

# %%
res=cross_val_score(dtc,house,lab,scoring="neg_mean_squared_error",cv=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-161e75c92f5c> in <module>
# ----> 1 res=cross_val_score(dtc,house,lab,scoring="neg_mean_squared_error",cv=5)
#
# NameError: name 'cross_val_score' is not defined

# %%
 lab=house_train['median_house_value']

# %%
lab

# %%
house=house_train.drop('median_house_value',axis=1)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1651 entries, 9584 to 9485
# Data columns (total 14 columns):
# longitude                     1651 non-null float64
# latitude                      1651 non-null float64
# housing_median_age            1651 non-null float64
# total_rooms                   1651 non-null float64
# total_bedrooms                1651 non-null float64
# population                    1651 non-null float64
# households                    1651 non-null float64
# median_income                 1651 non-null float64
# rph                           1651 non-null float64
# ocean_proximity_<1H OCEAN     1651 non-null uint8
# ocean_proximity_INLAND        1651 non-null uint8
# ocean_proximity_ISLAND        1651 non-null uint8
# ocean_proximity_NEAR BAY      1651 non-null uint8
# ocean_proximity_NEAR OCEAN    1651 non-null uint8
# dtypes: float64(9), uint8(5)
# memory usage: 137.0 KB

# %%
from sklearn import metrics

# %%
lr.fit(house,lab)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(house_copy)

# %%
labe=house_test["median_house_value"]

# %%
labe
# Out:
# 8849     500001.0
# 627      178900.0
# 13391    120400.0
# 6686     209200.0
# 14576    161400.0
# 19800     56700.0
# 13806     55500.0
# 14279     82700.0
# 11947    116000.0
# 5002     128000.0
# 16744    251500.0
# 8423     223300.0
# 20438    401900.0
# 1813     167800.0
# 15286    262100.0
# 7777     159700.0
# 13819    104100.0
# 10633    247100.0
# 17791    213100.0
# 16661    225000.0
# 15391    254100.0
# 12631     83400.0
# 13770    191600.0
# 1999      93900.0
# 8993     269100.0
# 15189    144600.0
# 7243     166300.0
# 15544    353000.0
# 6099     182700.0
# 16622    226900.0
#            ...
# 11887     82300.0
# 4516     122800.0
# 16554    120000.0
# 2262      67000.0
# 952      271100.0
# 19821    106300.0
# 6716     500001.0
# 19728     98200.0
# 11179    171400.0
# 16857    253000.0
# 2069      67900.0
# 6240     160300.0
# 2382     115300.0
# 12818    105300.0
# 3661     190000.0
# 8112     192700.0
# 18825     58600.0
# 7994     212600.0
# 7741     209000.0
# ...

# %%
house_copy=house_test.drop("median_house_value",axis=1)

# %%
y_pred
# Out:
# array([683172.68450728, 227003.07623728, 134956.25594147, ...,
#        152966.8500738 , 134291.47274038, 117995.83051767])

# %%
house_copy
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8849     -118.40     34.08                52.0       3815.0           439.0
# 627      -122.18     37.70                35.0       2562.0           554.0
# 13391    -117.59     34.09                16.0       2401.0           465.0
# 6686     -118.07     34.15                45.0       1095.0           237.0
# 14576    -117.20     32.83                35.0       1377.0           350.0
# 19800    -123.32     40.43                15.0        661.0           146.0
# 13806    -117.01     34.90                36.0       2181.0           555.0
# 14279    -117.13     32.71                38.0        993.0           246.0
# 11947    -117.44     33.93                34.0       1577.0           272.0
# 5002     -118.32     34.01                52.0       3104.0           645.0
# 16744    -122.45     37.71                49.0       2244.0           442.0
# ...

# %%
rmse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-31b3c02e10e9> in <module>
# ----> 1 rmse
#
# NameError: name 'rmse' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(house,labels,test_size=0.2,random_state=23)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 14196 to 15795
# Data columns (total 15 columns):
# longitude                     16512 non-null float64
# latitude                      16512 non-null float64
# housing_median_age            16512 non-null float64
# total_rooms                   16512 non-null float64
# total_bedrooms                16512 non-null float64
# population                    16512 non-null float64
# households                    16512 non-null float64
# median_income                 16512 non-null float64
# median_house_value            16512 non-null float64
# rph                           16512 non-null float64
# ocean_proximity_<1H OCEAN     16512 non-null uint8
# ocean_proximity_INLAND        16512 non-null uint8
# ocean_proximity_ISLAND        16512 non-null uint8
# ocean_proximity_NEAR BAY      16512 non-null uint8
# ocean_proximity_NEAR OCEAN    16512 non-null uint8
# dtypes: float64(10), uint8(5)
# memory usage: 1.5 MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128 entries, 20046 to 3665
# Data columns (total 10 columns):
# longitude             4128 non-null float64
# latitude              4128 non-null float64
# housing_median_age    4128 non-null float64
# total_rooms           4128 non-null float64
# total_bedrooms        4128 non-null float64
# population            4128 non-null float64
# households            4128 non-null float64
# median_income         4128 non-null float64
# median_house_value    4128 non-null float64
# ocean_proximity       4128 non-null object
# dtypes: float64(9), object(1)
# memory usage: 354.8+ KB

# %%
labels=housing["median_house_value"]

# %%
house=housing.drop("median_house_value",axis=1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 16067    -122.48     37.75                52.0       2074.0           401.0
# 12458    -114.62     33.62                26.0         18.0             3.0
# 16265    -121.27     37.96                41.0        461.0           101.0
# 15409    -117.24     33.22                20.0       1962.0           334.0
# 5624     -118.27     33.77                26.0       2272.0           694.0
# 14592    -117.17     32.82                21.0       2869.0           596.0
# 13930    -114.64     34.83                10.0       2502.0           573.0
# 20230    -119.29     34.26                32.0       3295.0           764.0
# 10151    -117.92     33.90                13.0       1814.0           320.0
# 2718     -115.57     32.80                16.0       2276.0           594.0
# ...

# %%
y_train
# Out:
# 865      269800.0
# 16067    331000.0
# 12458    275000.0
# 16265     54000.0
# 15409    162500.0
# 5624     150600.0
# 14592    197600.0
# 13930     86800.0
# 20230    395500.0
# 10151    337900.0
# 2718      93800.0
# 15659    225000.0
# 16310    155100.0
# 1909      97600.0
# 8040     221300.0
# 19891     48300.0
# 15108    166100.0
# 12766     88600.0
# 9589     117200.0
# 7720     244900.0
# 20032     77600.0
# 9342     414300.0
# 11153    219000.0
# 15095    147700.0
# 7122     160100.0
# 1238     103800.0
# 7182     131700.0
# 4272     193800.0
# 13840     85400.0
# 18362    500001.0
#            ...
# 912      298900.0
# 1345     162200.0
# 8699     279600.0
# 5786     209800.0
# 7192     143800.0
# 9727     231900.0
# 18496    160100.0
# 12357    248100.0
# 376       95200.0
# 7499      95900.0
# 6928     150900.0
# 5869     230400.0
# 5594     181500.0
# 13161    192200.0
# 2980      71400.0
# 20131    173400.0
# 19734     79100.0
# 16448     86900.0
# 4492     112500.0
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x_test)

# %%
y_pred=y_pred.reshape(-1,1)

# %%
result=cross_val_score(lr,y_test,y_pred,scoring="neg_mean_squared_error",cv=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-b1b8810cc892> in <module>
# ----> 1 result=cross_val_score(lr,y_test,y_pred,scoring="neg_mean_squared_error",cv=10)
#
# NameError: name 'cross_val_score' is not defined

# %%
y_test=np.array(y_test,ndmin=2)

# %%
y_pred
# Out:
# array([[675025.57364128],
#        [224646.34123781],
#        [136826.42025275],
#        ...,
#        [234020.26875506],
#        [177260.17615236],
#        [312804.07678401]])

# %%
y_pred
# Out:
# array([[675025.57364128],
#        [224646.34123781],
#        [136826.42025275],
#        ...,
#        [234020.26875506],
#        [177260.17615236],
#        [312804.07678401]])

# %%
y_test=y_test.T

# %%
res=np.sqrt(-result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-9af13ac0da7f> in <module>
# ----> 1 res=np.sqrt(-result)
#
# NameError: name 'result' is not defined

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-c08785e04264> in <module>
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_prediction=rfr.predict(x_test)

# %%
results=cross_val_score(rfr,y_test,y_prediction,scoring="neg_mean_squared_error",cv=10)

# %%
resu=np.sqrt(-results)

# %%
resu
# Out:
# array([51148.278656  , 51895.55032175, 56117.79908985, 54266.82958182,
#        48365.2827405 , 55130.4709678 , 51171.72012282, 51884.95876245,
#        51235.53410506, 55968.94098432])

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd=SGDRegressor(max_iter=50,penalty=None,eta0=0.005)

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.005, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=50,
#              n_iter_no_change=5, penalty=None, power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
res=sgd.predict(x_test)

# %%
res
# Out:
# array([6.21387765e+14, 6.04180910e+14, 6.64830933e+14, ...,
#        3.97987425e+14, 3.03208122e+14, 6.95268627e+14])

# %%
sgd.intercept_
# Out:
# array([6.67957339e+09])

# %%
sgd.coef_
# Out:
# array([-3.75402011e+11, -1.07055064e+11,  3.24266445e+11,  6.02627990e+10,
#        -5.05807041e+11,  1.53241654e+11,  8.83023721e+11, -1.21622216e+11,
#        -1.19654495e+11,  1.03678778e+11, -4.80880788e+10,  3.16908347e+09,
#        -4.92677794e+09, -4.71534314e+10])
