# %% [markdown]
# <a href="https://colab.research.google.com/github/Enish258/MLand-DL/blob/master/Catsvs_Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
train_dir='gdrive/My Drive/dataset/training_set'

# %%
test_dir='gdrive/My Drive/dataset/test_set'

# %%
train_dir
# Out:
# 'gdrive/My Drive/dataset/training_set'

# %%
len(os.listdir(test_dir))
# Out:
# 3

# %%
train_cats=os.path.join(train_dir,'cats')

# %%
train_dogs=os.path.join(train_dir,'dogs')

# %%
import os

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt 
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
for img in os.listdir(train_dogs):
  image=mpig.imread(os.path.join(train_dogs,img))
  plt.imshow(image)
  plt.show()
  break

# %%
import matplotlib.image as mpig

# %%
for image in os.listdir(train_cats):
  img=mpig.imread(os.path.join(train_cats,image))
  plt.imshow(img)
  plt.show()
  break

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_img=ImageDataGenerator(rescale=1./255)

# %%
train_gen=directory=train_train_img.flow_from_directory(dir,target_size=(size,size),batch_size=batch,shuffle=True,color_mode='rgb',class_mode='binary')
# Out:
# Found 5684 images belonging to 2 classes.

# %%
batch=32
size=150

# %%
model=tf.keras.Sequential([tf.keras.layers.Conv2D(32,(3,3),padding='same',activation=tf.nn.relu,input_shape=(150,150,3)),
                           tf.keras.layers.MaxPooling2D((2,2),strides=2),
                           tf.keras.layers.Conv2D(64,(3,3),padding='same',activation=tf.nn.relu),
                           tf.keras.layers.MaxPooling2D((2,2),strides=2),
                           tf.keras.layers.Conv2D(128,(3,3),padding='same',activation=tf.nn.relu),
                        tf.keras.layers.MaxPooling2D((2,2),strides=2),
                            tf.keras.layers.Conv2D(128,(3,3),padding='same',activation=tf.nn.relu),
                        tf.keras.layers.MaxPooling2D((2,2),strides=2),
                           tf.keras.layers.Flatten(),
                           tf.keras.layers.Dense(512,activation=tf.nn.relu),
                           tf.keras.layers.Dense(2,activation=tf.nn.softmax)])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(train_gen,epochs=10,shuffle=True,steps_per_epoch=math.ceil(5684/batch))
# Out:
# Epoch 1/10
# 178/178 [==============================] - 1483s 8s/step - loss: 0.5794 - acc: 0.7039
# Epoch 2/10
# 178/178 [==============================] - 24s 135ms/step - loss: 0.5233 - acc: 0.7386
# Epoch 3/10
# 178/178 [==============================] - 23s 131ms/step - loss: 0.4962 - acc: 0.7495
# Epoch 4/10
# 178/178 [==============================] - 24s 133ms/step - loss: 0.4564 - acc: 0.7901
# Epoch 5/10
# 178/178 [==============================] - 24s 134ms/step - loss: 0.4126 - acc: 0.8052
# Epoch 6/10
# 178/178 [==============================] - 23s 132ms/step - loss: 0.3630 - acc: 0.8353
# Epoch 7/10
# 178/178 [==============================] - 23s 131ms/step - loss: 0.3187 - acc: 0.8598
# Epoch 8/10
# 178/178 [==============================] - 23s 130ms/step - loss: 0.2551 - acc: 0.8893
# Epoch 9/10
# 178/178 [==============================] - 23s 131ms/step - loss: 0.1932 - acc: 0.9203
# Epoch 10/10
# ...

# %%
num=len(train_dir)

# %%
num
# Out:
# 36

# %%
num_cats=len(train_cats)

# %%
num_cats
# Out:
# 41

# %%
len(train_dogs)
# Out:
# 41

# %%
len(test_dir)
# Out:
# 32

# %%
len(os.listdir(train_cats))
# Out:
# 1685

# %%
len(os.listdir(train_dogs))
# Out:
# 4001

# %%
import math

# %%
test_gen=test_img.flow_from_directory(directory=test_dir,target_size=(size,size),color_mode='rgb',class_mode='binary',batch_size=batch,shuffle=True)
# Out:
# Found 0 images belonging to 2 classes.

# %%
import numpy as np

# %%
imag=np.asarray(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-80c8e1de9b82> in <module>()
# ----> 1 imag=np.asarray(img)
#
# NameError: name 'img' is not defined

# %%
plt.imshow(img)
plt.show()

# %%
img=mpig.imread(image)

# %%
image='gdrive/My Drive/dataset/training_set/cats/cat.11.jpg'

# %%
model.predict()

# %%
imag
# Out:
# array([[[235, 241, 237],
#         [231, 237, 233],
#         [213, 222, 219],
#         ...,
#         [ 61,  76,  57],
#         [ 58,  73,  54],
#         [ 53,  68,  49]],
#
#        [[249, 255, 253],
#         [235, 241, 239],
#         [207, 216, 213],
#         ...,
#         [ 62,  77,  58],
#         [ 61,  76,  57],
#         [ 57,  72,  53]],
#
#        [[242, 248, 248],
#         [223, 229, 229],
#         [194, 203, 202],
#         ...,
#         [ 63,  76,  58],
#         [ 63,  76,  58],
#         [ 59,  72,  54]],
#
#        ...,
#
#        [[ 89,  95, 107],
#         [125, 131, 143],
#         [170, 176, 188],
#         ...,
#         [199, 215, 240],
#         [199, 215, 240],
#         [199, 215, 238]],
#
#        [[ 87,  93, 107],
#         [113, 119, 133],
#         [133, 139, 153],
#         ...,
#         [198, 214, 239],
#         [202, 218, 243],
#         [201, 217, 240]],
#
#        [[ 89,  92, 107],
#         [115, 118, 133],
#         [135, 138, 153],
# ...

# %%
imag.shape
# Out:
# (410, 431, 3)

# %%
images=np.expand_dims(imag,axia)

# %%
pict=np.resize(imag,(224,224,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6078798f5d3e> in <module>()
# ----> 1 pict=np.resize(imag,(224,224,3))
#
# NameError: name 'np' is not defined
